# %% [markdown]
# # Reproduce query86 discrepancy on L40S

# %%
rapids_version = '24.12.0-SNAPSHOT'
gpu_type = 'l40s'
# gpu_type = 'h100'
use_decimal = True
# H100 has 2x memory, equalizing
gpu_mem_fraction = 0.5 if gpu_type == 'h100' else 1.0

# %%
from difflib import unified_diff
from glob import glob
from importlib.resources import files
import os
from pprint import pprint
import re
import sys

# %%
home_dir = os.getenv('HOME')

os.environ['SPARK_CONF_DIR'] = ""
os.environ['CUDA_VISIBLE_DEVICES'] = '0' if gpu_type == 'l40s' else '1'

os.environ['TZ'] = 'UTC'
sys.path.append(f"{home_dir}/gshegalov/gits/NVIDIA/spark-rapids-benchmarks/nds")
sys.path.append('/opt/spark-3.3.3-bin-hadoop3/python/lib/pyspark.zip')

py4j_src, *_ = glob('/opt/spark-3.3.3-bin-hadoop3/python/lib/py4j-*-src.zip')
sys.path.append(py4j_src)
import nds_power

# %%
spark_sql_jar_path, *_ = glob(f"/opt/spark-3.3.3-bin-hadoop3/jars/spark-sql_*jar")
spark_sql_jar = os.path.basename(spark_sql_jar_path)
scala_version = re.search(r'^spark-sql_(\d+.\d+)-.*\.jar$', spark_sql_jar).group(1)

# %%
# SNAPSHOT versions require a path since unpublished to Maven
rapids_artifact_id = f"rapids-4-spark_{scala_version}"

use_local_rapids_jar = True

if use_local_rapids_jar:

  # Binary Search
  
  # GOOD  
  # rapids_version = '24.10.0'

  # GOOD 
  # rapids_version = '24.12.0-20241015.184449-18'

  # GOOD 
  # rapids_version = '24.12.0-20241101.120509-33'

  # GOOD
  # rapids_version = '24.12.0-20241113.144142-42'

  # BAD
  rapids_version = '24.12.0-20241119.134850-43'
  
  # BAD
  # rapids_version = '24.12.0-20241122.132327-45'
  
  # BAD
  # rapids_version = '24.12.0-20241127.112105-48'
  
  # BAD
  # rapids_version = '24.12.0-20241203.104001-53'

  # BAD
  # rapids_version = '24.12.0-20241203.104001-53-cuda12'
  
  rapids_jar_path = f"/home/spark/gshegalov/dist/rapids/rapids-4-spark_2.12-{rapids_version}.jar"
else:
    rapids_jar_path = None

# %%
def dump_version_info(build_number):
  jar_path, *_ = glob(f"/home/spark/gshegalov/dist/rapids/rapids-4-spark_2.12-*-{build_number}.jar")
  version_files = [
    'rapids4spark-version-info.properties',
    'spark320/rapids4spark-private-version-info.properties',
    'spark-rapids-jni-version-info.properties',
    'cudf-java-version-info.properties'
  ]
  # !unzip -c {jar_path} {" ".join(version_files)}

# %%
# Last Good Jar
dump_version_info('42')
# Out:
# Archive:  /home/spark/gshegalov/dist/rapids/rapids-4-spark_2.12-24.12.0-20241113.144142-42.jar
#   inflating: spark320/rapids4spark-private-version-info.properties
# version=24.12.0-SNAPSHOT
# user=root
# revision=2f08e20170b66621d1f14ee0fb351ef5630ea811
# branch=HEAD
# date=2024-11-13T06:34:20Z
# url=https://gitlab-master.nvidia.com/nvspark/spark-rapids-private.git
#
#   inflating: rapids4spark-version-info.properties
# version=24.12.0-SNAPSHOT
# cudf_version=24.12.0-SNAPSHOT
# user=root
# revision=862dab0789abb95f860d1d42e06dad4690ca79e2
# branch=HEAD
# date=2024-11-13T14:24:52Z
# url=https://github.com/NVIDIA/spark-rapids.git
#
#   inflating: cudf-java-version-info.properties
# version=24.12.0-SNAPSHOT
# user=root
# revision=487f97c036ae7919e98ddc8bf5412a8002a493c5
# branch=HEAD
# date=2024-11-13T08:01:08Z
# url=https://github.com/rapidsai/cudf.git
# gpu_architectures=70;75;80;86;90
#
#   inflating: spark-rapids-jni-version-info.properties
# version=24.12.0-SNAPSHOT
# user=root
# revision=ea47ecb58cab8228a81088b8ac44e3b336a9ba7e
# branch=HEAD
# date=2024-11-13T08:01:12Z
# url=https://github.com/NVIDIA/spark-rapids-jni.git
# gpu_architectures=70;75;80;86;90

# %%
# First Bad Jar 
dump_version_info('43')
# Out:
# Archive:  /home/spark/gshegalov/dist/rapids/rapids-4-spark_2.12-24.12.0-20241119.134850-43.jar
#   inflating: spark320/rapids4spark-private-version-info.properties
# version=24.12.0-SNAPSHOT
# user=root
# revision=2f08e20170b66621d1f14ee0fb351ef5630ea811
# branch=HEAD
# date=2024-11-19T06:37:56Z
# url=https://gitlab-master.nvidia.com/nvspark/spark-rapids-private.git
#
#   inflating: rapids4spark-version-info.properties
# version=24.12.0-SNAPSHOT
# cudf_version=24.12.0-SNAPSHOT
# user=root
# revision=9b06ae3081d969abdd02686c50741e20a637ef7d
# branch=HEAD
# date=2024-11-19T13:34:11Z
# url=https://github.com/NVIDIA/spark-rapids.git
#
#   inflating: cudf-java-version-info.properties
# version=24.12.0-SNAPSHOT
# user=root
# revision=302e625bf87dce4059eb7c383dced848ad9d8f4c
# branch=HEAD
# date=2024-11-19T08:10:37Z
# url=https://github.com/rapidsai/cudf.git
# gpu_architectures=70;75;80;86;90
#
#   inflating: spark-rapids-jni-version-info.properties
# version=24.12.0-SNAPSHOT
# user=root
# revision=e3fd02e4a3b7567dc08f78ee75f3c2bd0ee6d03a
# branch=HEAD
# date=2024-11-19T08:10:40Z
# url=https://github.com/NVIDIA/spark-rapids-jni.git
# gpu_architectures=70;75;80;86;90

# %%
from pyspark.sql import SparkSession
num_execs = 1
cores_per_exec = 8

spark_builder = (
    SparkSession.builder
        .appName('NDS Query Notebook')
        # .master('local[96]')
        .master(f"local-cluster[{num_execs},{cores_per_exec},{cores_per_exec * 1024}]")
        .config('spark.driver.memory', '24g')
        .config('spark.executorEnv.TZ', 'UTC')
        .config('spark.plugins', 'com.nvidia.spark.SQLPlugin')
        .config('spark.rapids.memory.gpu.minAllocFraction', 0)
        .config('spark.rapids.memory.gpu.allocFraction', gpu_mem_fraction / num_execs)
        .config('spark.rapids.memory.gpu.maxAllocFraction', gpu_mem_fraction / num_execs)
        # .config('spark.rapids.sql.explain', 'ALL')
        .config('spark.sql.files.maxPartitionBytes', '128mb')
        .config("spark.sql.shuffle.partitions", 1152)
        .config('spark.worker.resource.gpu.discoveryScript', f"/opt/getGpusResources-{gpu_type}.sh")
        .config('spark.worker.resource.gpu.amount', 1)
        .config('spark.ui.showConsoleProgress', False)
)

if rapids_jar_path is not None:
    spark_builder.config('spark.driver.extraClassPath', rapids_jar_path)
    spark_builder.config('spark.executor.extraClassPath', rapids_jar_path)
else:
    rapids_version = '24.12.0-SNAPSHOT'
    spark_builder.config('spark.jars.packages', f"com.nvidia:{rapids_artifact_id}:{rapids_version}")
spark = spark_builder.getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/12/06 21:58:46 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 24/12/06 21:58:47 WARN RapidsPluginUtils: RAPIDS Accelerator 24.12.0-SNAPSHOT using cudf 24.12.0-SNAPSHOT, private revision 2f08e20170b66621d1f14ee0fb351ef5630ea811
# 24/12/06 21:58:47 WARN RapidsPluginUtils: RAPIDS Accelerator is enabled, to disable GPU support set `spark.rapids.sql.enabled` to false.
# 24/12/06 21:58:47 WARN RapidsPluginUtils: spark.rapids.sql.explain is set to `NOT_ON_GPU`. Set it to 'NONE' to suppress the diagnostics logging about the query placement on the GPU.
# 24/12/06 21:58:47 WARN Master: App app-20241206215847-0000 requires more resource than any of Workers could have.

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://sparkh-06.nvidia.com:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local-cluster[1,8,8192]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>NDS Query Notebook</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# # Setup NDS Tables

# %%
nds_scale_factor = 'sf3k'
nds_data_path = f"{nds_data_root}/parquet_{nds_scale_factor}_decimal"
print(f"##### Setting up tables: {use_decimal=} #####")
nds_power.setup_tables(spark, nds_data_path, 'parquet', use_decimal, [])
# Out:
# ##### Setting up tables: use_decimal=True #####
# 24/12/06 21:58:48 WARN DomainSocketFactory: The short-circuit local reads feature cannot be used because libhadoop cannot be loaded.
# ====== Creating TempView for table customer_address ======
# Time taken: 9314 millis for table customer_address
# ====== Creating TempView for table customer_demographics ======
# Time taken: 112 millis for table customer_demographics
# 24/12/06 21:58:58 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# ====== Creating TempView for table date_dim ======
# Time taken: 113 millis for table date_dim
# ====== Creating TempView for table warehouse ======
# Time taken: 97 millis for table warehouse
# ====== Creating TempView for table ship_mode ======
# Time taken: 87 millis for table ship_mode
# ====== Creating TempView for table time_dim ======
# Time taken: 82 millis for table time_dim
# ====== Creating TempView for table reason ======
# Time taken: 77 millis for table reason
# ====== Creating TempView for table income_band ======
# Time taken: 82 millis for table income_band
# ====== Creating TempView for table item ======
# Time taken: 79 millis for table item
# ====== Creating TempView for table store ======
# Time taken: 84 millis for table store
# ====== Creating TempView for table call_center ======
# Time taken: 89 millis for table call_center
# ====== Creating TempView for table customer ======
# Time taken: 69 millis for table customer
# ====== Creating TempView for table web_site ======
# Time taken: 71 millis for table web_site
# ====== Creating TempView for table store_returns ======
# Time taken: 5033 millis for table store_returns
# ====== Creating TempView for table household_demographics ======
# Time taken: 160 millis for table household_demographics
# ====== Creating TempView for table web_page ======
# Time taken: 69 millis for table web_page
# ====== Creating TempView for table promotion ======
# Time taken: 65 millis for table promotion
# ====== Creating TempView for table catalog_page ======
# Time taken: 63 millis for table catalog_page
# ====== Creating TempView for table inventory ======
# Time taken: 673 millis for table inventory
# ====== Creating TempView for table catalog_returns ======
# Time taken: 4958 millis for table catalog_returns
# ====== Creating TempView for table web_returns ======
# Time taken: 5189 millis for table web_returns
# ====== Creating TempView for table web_sales ======
# Time taken: 4156 millis for table web_sales
# ====== Creating TempView for table catalog_sales ======
# Time taken: 4267 millis for table catalog_sales
# ====== Creating TempView for table store_sales ======
# Time taken: 4361 millis for table store_sales
# [('app-20241206215847-0000', 'CreateTempView customer_address', 9314),
#  ('app-20241206215847-0000', 'CreateTempView customer_demographics', 112),
#  ('app-20241206215847-0000', 'CreateTempView date_dim', 113),
#  ('app-20241206215847-0000', 'CreateTempView warehouse', 97),
#  ('app-20241206215847-0000', 'CreateTempView ship_mode', 87),
#  ('app-20241206215847-0000', 'CreateTempView time_dim', 82),
#  ('app-20241206215847-0000', 'CreateTempView reason', 77),
#  ('app-20241206215847-0000', 'CreateTempView income_band', 82),
#  ('app-20241206215847-0000', 'CreateTempView item', 79),
#  ('app-20241206215847-0000', 'CreateTempView store', 84),
#  ('app-20241206215847-0000', 'CreateTempView call_center', 89),
#  ('app-20241206215847-0000', 'CreateTempView customer', 69),
#  ('app-20241206215847-0000', 'CreateTempView web_site', 71),
#  ('app-20241206215847-0000', 'CreateTempView store_returns', 5033),
#  ('app-20241206215847-0000', 'CreateTempView household_demographics', 160),
#  ('app-20241206215847-0000', 'CreateTempView web_page', 69),
#  ('app-20241206215847-0000', 'CreateTempView promotion', 65),
#  ('app-20241206215847-0000', 'CreateTempView catalog_page', 63),
#  ('app-20241206215847-0000', 'CreateTempView inventory', 673),
#  ('app-20241206215847-0000', 'CreateTempView catalog_returns', 4958),
#  ('app-20241206215847-0000', 'CreateTempView web_returns', 5189),
#  ('app-20241206215847-0000', 'CreateTempView web_sales', 4156),
#  ('app-20241206215847-0000', 'CreateTempView catalog_sales', 4267),
#  ('app-20241206215847-0000', 'CreateTempView store_sales', 4361)]

# %% [markdown]
# # Verify executor on the right GPU ID

# %%
pid = os.getpid()
# !pstree -T -p {pid}
# Out:
# python(669569)─┬─java(669696)───java(670412)
#                └─pstree(670972)

# %%
# !nvidia-smi
# Out:
# Fri Dec  6 21:59:28 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.35.03              Driver Version: 560.35.03      CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L40S                    Off |   00000000:01:00.0 Off |                    0 |
# | N/A   47C    P0             88W /  350W |   44863MiB /  46068MiB |      0%   E. Process |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  NVIDIA H100 NVL                Off |   00000000:A1:00.0 Off |                    0 |
# | N/A   42C    P0             65W /  400W |       1MiB /  95830MiB |      0%   E. Process |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A    670412      C   ...m/java-1.8.0-openjdk-amd64/bin/java      44854MiB |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# # Run Queries from internal_git/ab/-/blob/main/query_streams/nds/sf3k_query_0.sql#L841-870

# %%
queries = {

  
  'q36': '''
select
    sum(ss_net_profit)/sum(ss_ext_sales_price) as gross_margin
   ,i_category
   ,i_class
   ,grouping(i_category)+grouping(i_class) as lochierarchy
   ,rank() over (
        partition by grouping(i_category)+grouping(i_class),
        case when grouping(i_class) = 0 then i_category end
        order by sum(ss_net_profit)/sum(ss_ext_sales_price) asc) as rank_within_parent
 from
    store_sales
   ,date_dim       d1
   ,item
   ,store
 where
    d1.d_year = 2002
 and d1.d_date_sk = ss_sold_date_sk
 and i_item_sk  = ss_item_sk
 and s_store_sk  = ss_store_sk
 and s_state in ('MN','TN','MI','WV',
                 'NC','GA','TN','OH')
 group by rollup(i_category,i_class)
 order by
   lochierarchy desc
  ,case when lochierarchy = 0 then i_category end
  ,rank_within_parent
   LIMIT 100;
''',

  
   'q86': '''
select
    sum(ws_net_paid) as total_sum
   ,i_category
   ,i_class
   ,grouping(i_category)+grouping(i_class) as lochierarchy
   ,rank() over (
        partition by grouping(i_category)+grouping(i_class),
        case when grouping(i_class) = 0 then i_category end
        order by sum(ws_net_paid) desc) as rank_within_parent
 from
    web_sales
   ,date_dim       d1
   ,item
 where
    d1.d_month_seq between 1205 and 1205+11
 and d1.d_date_sk = ws_sold_date_sk
 and i_item_sk  = ws_item_sk
 group by rollup(i_category,i_class)
 order by
   lochierarchy desc,
   case when lochierarchy = 0 then i_category end,
   rank_within_parent
'''
}

# %%
def compare_cpu_gpu():
  for qid, sql_text in queries.items():       
    print(f"##### Runing {qid=} {use_decimal=} on CPU #####")
    spark.conf.set('spark.rapids.sql.enabled', False)
    cpu_df = spark.sql(sql_text)
    cpu_df.printSchema()
    cpu = sorted(cpu_df.collect())
    print("######### BEGIN Full CPU OUTPUT for REFERENCE #####")
    pprint(cpu)
    print("######### END Full CPU OUTPUT for REFERENCE #####")
  
    print(f"##### Runing {qid=} {use_decimal=} on GPU #####")
    spark.conf.set('spark.rapids.sql.enabled', True)
    gpu_df = spark.sql(sql_text)
    gpu_df.printSchema()
    gpu = sorted(gpu_df.collect())
    print("######### BEGIN Full GPU OUTPUT for REFERENCE #####")
    pprint(gpu)
    print("######### END Full GPU OUTPUT for REFERENCE #####")
  
    print(f"#### checking diff {qid=} {use_decimal=} ####")
    sys.stdout.writelines(unified_diff(
      a=[f"{x}\n" for x in cpu],
      b=[f"{x}\n" for x in gpu],
      fromfile='CPU OUTPUT',
      tofile='GPU OUTPUT'))  
    assert gpu == cpu, f"##### Check for diff of {qid=} {use_decimal=} above #####"
    print(f"#### SUCSESS {qid=} {use_decimal=} GPU and CPU matched ####")
  print(f"##### END of REPRO on {gpu_type=} #####")

# %%
compare_cpu_gpu()
# Out:
# ##### Runing qid='q36' use_decimal=True on CPU #####
# root
#  |-- gross_margin: decimal(37,20) (nullable = true)
#  |-- i_category: string (nullable = true)
#  |-- i_class: string (nullable = true)
#  |-- lochierarchy: byte (nullable = false)
#  |-- rank_within_parent: integer (nullable = false)
#
# ######### BEGIN Full CPU OUTPUT for REFERENCE #####
# [Row(gross_margin=Decimal('-0.47828295516352641128'), i_category=None, i_class='audio', lochierarchy=0, rank_within_parent=1),
#  Row(gross_margin=Decimal('-0.47230074709745873202'), i_category=None, i_class='history', lochierarchy=0, rank_within_parent=2),
#  Row(gross_margin=Decimal('-0.46715300295799058210'), i_category=None, i_class='swimwear', lochierarchy=0, rank_within_parent=3),
#  Row(gross_margin=Decimal('-0.46668415445196648666'), i_category=None, i_class='archery', lochierarchy=0, rank_within_parent=4),
#  Row(gross_margin=Decimal('-0.46536094067172816315'), i_category=None, i_class='cooking', lochierarchy=0, rank_within_parent=5),
#  Row(gross_margin=Decimal('-0.46526659482305280665'), i_category=None, i_class='decor', lochierarchy=0, rank_within_parent=6),
#  Row(gross_margin=Decimal('-0.46499772499425652100'), i_category=None, i_class='camcorders', lochierarchy=0, rank_within_parent=7),
#  Row(gross_margin=Decimal('-0.45711650089137390740'), i_category=None, i_class='costume', lochierarchy=0, rank_within_parent=8),
#  Row(gross_margin=Decimal('-0.45617405808999092989'), i_category=None, i_class='accessories', lochierarchy=0, rank_within_parent=9),
#  Row(gross_margin=Decimal('-0.45502041199089195990'), i_category=None, i_class='personal', lochierarchy=0, rank_within_parent=10),
#  Row(gross_margin=Decimal('-0.45149107975305018384'), i_category=None, i_class='sports-apparel', lochierarchy=0, rank_within_parent=11),
#  Row(gross_margin=Decimal('-0.45121154484672231782'), i_category=None, i_class='dvd/vcr players', lochierarchy=0, rank_within_parent=12),
#  Row(gross_margin=Decimal('-0.44989148230981810568'), i_category=None, i_class='paint', lochierarchy=0, rank_within_parent=13),
#  Row(gross_margin=Decimal('-0.44815811288106521357'), i_category=None, i_class='shirts', lochierarchy=0, rank_within_parent=14),
#  Row(gross_margin=Decimal('-0.44713571159860328726'), i_category=None, i_class='self-help', lochierarchy=0, rank_within_parent=15),
#  Row(gross_margin=Decimal('-0.44645879452077128200'), i_category=None, i_class='mens watch', lochierarchy=0, rank_within_parent=16),
#  Row(gross_margin=Decimal('-0.44588433060550519717'), i_category=None, i_class='classical', lochierarchy=0, rank_within_parent=17),
#  Row(gross_margin=Decimal('-0.44570467384548738791'), i_category=None, i_class='newborn', lochierarchy=0, rank_within_parent=18),
#  Row(gross_margin=Decimal('-0.44564507142834691119'), i_category=None, i_class='memory', lochierarchy=0, rank_within_parent=19),
#  Row(gross_margin=Decimal('-0.44543738086109094255'), i_category=None, i_class='tables', lochierarchy=0, rank_within_parent=20),
#  Row(gross_margin=Decimal('-0.44344653798305018959'), i_category=None, i_class='pants', lochierarchy=0, rank_within_parent=21),
#  Row(gross_margin=Decimal('-0.44288908944036071990'), i_category=None, i_class='pendants', lochierarchy=0, rank_within_parent=22),
#  Row(gross_margin=Decimal('-0.44098188193222754755'), i_category=None, i_class='mens', lochierarchy=0, rank_within_parent=23),
#  Row(gross_margin=Decimal('-0.43997655470655225031'), i_category=None, i_class='womens', lochierarchy=0, rank_within_parent=24),
#  Row(gross_margin=Decimal('-0.43975463650846117925'), i_category=None, i_class='fitness', lochierarchy=0, rank_within_parent=25),
#  Row(gross_margin=Decimal('-0.43929872967931892316'), i_category=None, i_class='consignment', lochierarchy=0, rank_within_parent=26),
#  Row(gross_margin=Decimal('-0.43873972046053225129'), i_category=None, i_class='bracelets', lochierarchy=0, rank_within_parent=27),
#  Row(gross_margin=Decimal('-0.43713181734844977318'), i_category=None, i_class='pools', lochierarchy=0, rank_within_parent=28),
#  Row(gross_margin=Decimal('-0.43690130702015180996'), i_category=None, i_class='fragrances', lochierarchy=0, rank_within_parent=29),
#  Row(gross_margin=Decimal('-0.43677737197671834195'), i_category=None, i_class='school-uniforms', lochierarchy=0, rank_within_parent=30),
#  Row(gross_margin=Decimal('-0.43663290999258552250'), i_category=None, i_class='guns', lochierarchy=0, rank_within_parent=31),
#  Row(gross_margin=Decimal('-0.43635203005695492845'), i_category=None, i_class='science', lochierarchy=0, rank_within_parent=32),
#  Row(gross_margin=Decimal('-0.43627793029695402466'), i_category=None, i_class='birdal', lochierarchy=0, rank_within_parent=33),
#  Row(gross_margin=Decimal('-0.43615621657745683634'), i_category=None, i_class='televisions', lochierarchy=0, rank_within_parent=34),
#  Row(gross_margin=Decimal('-0.43597605430243640408'), i_category=None, i_class='country', lochierarchy=0, rank_within_parent=35),
#  Row(gross_margin=Decimal('-0.43561555928707419008'), i_category=None, i_class=None, lochierarchy=1, rank_within_parent=1),
#  Row(gross_margin=Decimal('-0.43561435861342959823'), i_category=None, i_class='rock', lochierarchy=0, rank_within_parent=36),
#  Row(gross_margin=Decimal('-0.43550771956473883152'), i_category=None, i_class='maternity', lochierarchy=0, rank_within_parent=37),
#  Row(gross_margin=Decimal('-0.43527663623738803430'), i_category=None, i_class=None, lochierarchy=0, rank_within_parent=38),
#  Row(gross_margin=Decimal('-0.43501597744051964618'), i_category=None, i_class='kids', lochierarchy=0, rank_within_parent=39),
#  Row(gross_margin=Decimal('-0.43495471799620629023'), i_category=None, i_class='camping', lochierarchy=0, rank_within_parent=40),
#  Row(gross_margin=Decimal('-0.43473993133124046911'), i_category=None, i_class='golf', lochierarchy=0, rank_within_parent=41),
#  Row(gross_margin=Decimal('-0.43463769267498883720'), i_category='Books', i_class='fiction', lochierarchy=0, rank_within_parent=1),
#  Row(gross_margin=Decimal('-0.43452776378667850951'), i_category='Books', i_class='reference', lochierarchy=0, rank_within_parent=2),
#  Row(gross_margin=Decimal('-0.43447486026854350876'), i_category='Books', i_class=None, lochierarchy=0, rank_within_parent=3),
#  Row(gross_margin=Decimal('-0.43447020920809058183'), i_category='Books', i_class='computers', lochierarchy=0, rank_within_parent=4),
#  Row(gross_margin=Decimal('-0.43428999042082383658'), i_category=None, i_class='romance', lochierarchy=0, rank_within_parent=42),
#  Row(gross_margin=Decimal('-0.43422584143830548495'), i_category='Books', i_class='cooking', lochierarchy=0, rank_within_parent=5),
#  Row(gross_margin=Decimal('-0.43414366878464396368'), i_category=None, i_class='infants', lochierarchy=0, rank_within_parent=43),
#  Row(gross_margin=Decimal('-0.43404897731623584759'), i_category='Books', i_class='history', lochierarchy=0, rank_within_parent=6),
#  Row(gross_margin=Decimal('-0.43376882693575818716'), i_category='Jewelry', i_class=None, lochierarchy=1, rank_within_parent=2),
#  Row(gross_margin=Decimal('-0.43371349466003111712'), i_category='Music', i_class=None, lochierarchy=1, rank_within_parent=3),
#  Row(gross_margin=Decimal('-0.43367159423014962013'), i_category='Sports', i_class=None, lochierarchy=1, rank_within_parent=4),
#  Row(gross_margin=Decimal('-0.43360519550777610415'), i_category='Men', i_class=None, lochierarchy=1, rank_within_parent=5),
#  Row(gross_margin=Decimal('-0.43358989475350213383'), i_category='Women', i_class=None, lochierarchy=1, rank_within_parent=6),
#  Row(gross_margin=Decimal('-0.43358627728306443926'), i_category=None, i_class=None, lochierarchy=2, rank_within_parent=1),
#  Row(gross_margin=Decimal('-0.43353995228987259047'), i_category='Shoes', i_class=None, lochierarchy=1, rank_within_parent=7),
#  Row(gross_margin=Decimal('-0.43353747033700003969'), i_category='Books', i_class=None, lochierarchy=1, rank_within_parent=8),
#  Row(gross_margin=Decimal('-0.43349539873648945556'), i_category='Children', i_class=None, lochierarchy=1, rank_within_parent=9),
#  Row(gross_margin=Decimal('-0.43348694025710119921'), i_category='Home', i_class=None, lochierarchy=1, rank_within_parent=10),
#  Row(gross_margin=Decimal('-0.43342670574593757218'), i_category=None, i_class='toddlers', lochierarchy=0, rank_within_parent=44),
#  Row(gross_margin=Decimal('-0.43340485165479664221'), i_category='Electronics', i_class=None, lochierarchy=1, rank_within_parent=11),
#  Row(gross_margin=Decimal('-0.43340446329714668500'), i_category=None, i_class='musical', lochierarchy=0, rank_within_parent=45),
#  Row(gross_margin=Decimal('-0.43326865631149291828'), i_category=None, i_class='reference', lochierarchy=0, rank_within_parent=46),
#  Row(gross_margin=Decimal('-0.43325549083761292687'), i_category=None, i_class='diamonds', lochierarchy=0, rank_within_parent=47),
#  Row(gross_margin=Decimal('-0.43193082872314780811'), i_category=None, i_class='athletic', lochierarchy=0, rank_within_parent=48),
#  Row(gross_margin=Decimal('-0.43181629529070380726'), i_category=None, i_class='tennis', lochierarchy=0, rank_within_parent=49),
#  Row(gross_margin=Decimal('-0.43173620765961707768'), i_category=None, i_class='lighting', lochierarchy=0, rank_within_parent=50),
#  Row(gross_margin=Decimal('-0.43137253755689801662'), i_category=None, i_class='basketball', lochierarchy=0, rank_within_parent=51),
#  Row(gross_margin=Decimal('-0.43062608877945132099'), i_category=None, i_class='optics', lochierarchy=0, rank_within_parent=52),
#  Row(gross_margin=Decimal('-0.42926236666984711593'), i_category=None, i_class='arts', lochierarchy=0, rank_within_parent=53),
#  Row(gross_margin=Decimal('-0.42885057637972905225'), i_category=None, i_class='disk drives', lochierarchy=0, rank_within_parent=54),
#  Row(gross_margin=Decimal('-0.42883895337303757123'), i_category=None, i_class='earings', lochierarchy=0, rank_within_parent=55),
#  Row(gross_margin=Decimal('-0.42815705038826697011'), i_category=None, i_class='scanners', lochierarchy=0, rank_within_parent=56),
#  Row(gross_margin=Decimal('-0.42789628991180642042'), i_category=None, i_class='flatware', lochierarchy=0, rank_within_parent=57),
#  Row(gross_margin=Decimal('-0.42751393108325494927'), i_category=None, i_class='rugs', lochierarchy=0, rank_within_parent=58),
#  Row(gross_margin=Decimal('-0.42703891331468818542'), i_category=None, i_class='computers', lochierarchy=0, rank_within_parent=59),
#  Row(gross_margin=Decimal('-0.42687500164053020735'), i_category=None, i_class='glassware', lochierarchy=0, rank_within_parent=60),
#  Row(gross_margin=Decimal('-0.42552101984012148225'), i_category=None, i_class='fishing', lochierarchy=0, rank_within_parent=61),
#  Row(gross_margin=Decimal('-0.42476260982538582676'), i_category=None, i_class='womens watch', lochierarchy=0, rank_within_parent=62),
#  Row(gross_margin=Decimal('-0.42452851303971651810'), i_category=None, i_class='parenting', lochierarchy=0, rank_within_parent=63),
#  Row(gross_margin=Decimal('-0.42339149149768885699'), i_category=None, i_class='furniture', lochierarchy=0, rank_within_parent=64),
#  Row(gross_margin=Decimal('-0.42168352304902960657'), i_category=None, i_class='outdoor', lochierarchy=0, rank_within_parent=65),
#  Row(gross_margin=Decimal('-0.42143177556841967050'), i_category=None, i_class='curtains/drapes', lochierarchy=0, rank_within_parent=66),
#  Row(gross_margin=Decimal('-0.42120834921200342268'), i_category=None, i_class='dresses', lochierarchy=0, rank_within_parent=67),
#  Row(gross_margin=Decimal('-0.42001482343846840492'), i_category=None, i_class='pop', lochierarchy=0, rank_within_parent=68),
#  Row(gross_margin=Decimal('-0.41995134951751466646'), i_category=None, i_class='karoke', lochierarchy=0, rank_within_parent=69),
#  Row(gross_margin=Decimal('-0.41959982259002413551'), i_category=None, i_class='sports', lochierarchy=0, rank_within_parent=70),
#  Row(gross_margin=Decimal('-0.41650088646249658534'), i_category=None, i_class='custom', lochierarchy=0, rank_within_parent=71),
#  Row(gross_margin=Decimal('-0.41588027531636796036'), i_category=None, i_class='automotive', lochierarchy=0, rank_within_parent=72),
#  Row(gross_margin=Decimal('-0.41500139895405487419'), i_category=None, i_class='travel', lochierarchy=0, rank_within_parent=73),
#  Row(gross_margin=Decimal('-0.41484497717797805148'), i_category=None, i_class='loose stones', lochierarchy=0, rank_within_parent=74),
#  Row(gross_margin=Decimal('-0.41046619711072709563'), i_category=None, i_class='football', lochierarchy=0, rank_within_parent=75),
#  Row(gross_margin=Decimal('-0.40766856021119107858'), i_category=None, i_class='rings', lochierarchy=0, rank_within_parent=76),
#  Row(gross_margin=Decimal('-0.40507693120675812824'), i_category=None, i_class='home repair', lochierarchy=0, rank_within_parent=77),
#  Row(gross_margin=Decimal('-0.40306239716291443732'), i_category=None, i_class='portable', lochierarchy=0, rank_within_parent=78),
#  Row(gross_margin=Decimal('-0.40118362437320425343'), i_category=None, i_class='estate', lochierarchy=0, rank_within_parent=79),
#  Row(gross_margin=Decimal('-0.40118360571745636940'), i_category=None, i_class='athletic shoes', lochierarchy=0, rank_within_parent=80),
#  Row(gross_margin=Decimal('-0.39111306499480281681'), i_category=None, i_class='monitors', lochierarchy=0, rank_within_parent=81),
#  Row(gross_margin=Decimal('-0.36708489506031944778'), i_category=None, i_class='semi-precious', lochierarchy=0, rank_within_parent=82)]
# ######### END Full CPU OUTPUT for REFERENCE #####
# ##### Runing qid='q36' use_decimal=True on GPU #####
# root
#  |-- gross_margin: decimal(37,20) (nullable = true)
#  |-- i_category: string (nullable = true)
#  |-- i_class: string (nullable = true)
#  |-- lochierarchy: byte (nullable = false)
#  |-- rank_within_parent: integer (nullable = false)
#
# ######### BEGIN Full GPU OUTPUT for REFERENCE #####
# [Row(gross_margin=Decimal('-0.47828295516352641128'), i_category=None, i_class='audio', lochierarchy=0, rank_within_parent=1),
#  Row(gross_margin=Decimal('-0.47230074709745873202'), i_category=None, i_class='history', lochierarchy=0, rank_within_parent=2),
#  Row(gross_margin=Decimal('-0.46715300295799058210'), i_category=None, i_class='swimwear', lochierarchy=0, rank_within_parent=3),
#  Row(gross_margin=Decimal('-0.46668415445196648666'), i_category=None, i_class='archery', lochierarchy=0, rank_within_parent=4),
#  Row(gross_margin=Decimal('-0.46536094067172816315'), i_category=None, i_class='cooking', lochierarchy=0, rank_within_parent=5),
#  Row(gross_margin=Decimal('-0.46526659482305280665'), i_category=None, i_class='decor', lochierarchy=0, rank_within_parent=6),
#  Row(gross_margin=Decimal('-0.46499772499425652100'), i_category=None, i_class='camcorders', lochierarchy=0, rank_within_parent=7),
#  Row(gross_margin=Decimal('-0.45711650089137390740'), i_category=None, i_class='costume', lochierarchy=0, rank_within_parent=8),
#  Row(gross_margin=Decimal('-0.45617405808999092989'), i_category=None, i_class='accessories', lochierarchy=0, rank_within_parent=9),
#  Row(gross_margin=Decimal('-0.45502041199089195990'), i_category=None, i_class='personal', lochierarchy=0, rank_within_parent=10),
#  Row(gross_margin=Decimal('-0.45149107975305018384'), i_category=None, i_class='sports-apparel', lochierarchy=0, rank_within_parent=11),
#  Row(gross_margin=Decimal('-0.45121154484672231782'), i_category=None, i_class='dvd/vcr players', lochierarchy=0, rank_within_parent=12),
#  Row(gross_margin=Decimal('-0.44989148230981810568'), i_category=None, i_class='paint', lochierarchy=0, rank_within_parent=13),
#  Row(gross_margin=Decimal('-0.44815811288106521357'), i_category=None, i_class='shirts', lochierarchy=0, rank_within_parent=14),
#  Row(gross_margin=Decimal('-0.44713571159860328726'), i_category=None, i_class='self-help', lochierarchy=0, rank_within_parent=15),
#  Row(gross_margin=Decimal('-0.44645879452077128200'), i_category=None, i_class='mens watch', lochierarchy=0, rank_within_parent=16),
#  Row(gross_margin=Decimal('-0.44588433060550519717'), i_category=None, i_class='classical', lochierarchy=0, rank_within_parent=17),
#  Row(gross_margin=Decimal('-0.44570467384548738791'), i_category=None, i_class='newborn', lochierarchy=0, rank_within_parent=18),
#  Row(gross_margin=Decimal('-0.44564507142834691119'), i_category=None, i_class='memory', lochierarchy=0, rank_within_parent=19),
#  Row(gross_margin=Decimal('-0.44543738086109094255'), i_category=None, i_class='tables', lochierarchy=0, rank_within_parent=20),
#  Row(gross_margin=Decimal('-0.44344653798305018959'), i_category=None, i_class='pants', lochierarchy=0, rank_within_parent=21),
#  Row(gross_margin=Decimal('-0.44288908944036071990'), i_category=None, i_class='pendants', lochierarchy=0, rank_within_parent=22),
#  Row(gross_margin=Decimal('-0.44098188193222754755'), i_category=None, i_class='mens', lochierarchy=0, rank_within_parent=23),
#  Row(gross_margin=Decimal('-0.43997655470655225031'), i_category=None, i_class='womens', lochierarchy=0, rank_within_parent=24),
#  Row(gross_margin=Decimal('-0.43975463650846117925'), i_category=None, i_class='fitness', lochierarchy=0, rank_within_parent=25),
#  Row(gross_margin=Decimal('-0.43929872967931892316'), i_category=None, i_class='consignment', lochierarchy=0, rank_within_parent=26),
#  Row(gross_margin=Decimal('-0.43873972046053225129'), i_category=None, i_class='bracelets', lochierarchy=0, rank_within_parent=27),
#  Row(gross_margin=Decimal('-0.43713181734844977318'), i_category=None, i_class='pools', lochierarchy=0, rank_within_parent=28),
#  Row(gross_margin=Decimal('-0.43690130702015180996'), i_category=None, i_class='fragrances', lochierarchy=0, rank_within_parent=29),
#  Row(gross_margin=Decimal('-0.43677737197671834195'), i_category=None, i_class='school-uniforms', lochierarchy=0, rank_within_parent=30),
#  Row(gross_margin=Decimal('-0.43663290999258552250'), i_category=None, i_class='guns', lochierarchy=0, rank_within_parent=31),
#  Row(gross_margin=Decimal('-0.43635203005695492845'), i_category=None, i_class='science', lochierarchy=0, rank_within_parent=32),
#  Row(gross_margin=Decimal('-0.43627793029695402466'), i_category=None, i_class='birdal', lochierarchy=0, rank_within_parent=33),
#  Row(gross_margin=Decimal('-0.43615621657745683634'), i_category=None, i_class='televisions', lochierarchy=0, rank_within_parent=34),
#  Row(gross_margin=Decimal('-0.43597605430243640408'), i_category=None, i_class='country', lochierarchy=0, rank_within_parent=35),
#  Row(gross_margin=Decimal('-0.43561555928707419008'), i_category=None, i_class=None, lochierarchy=1, rank_within_parent=1),
#  Row(gross_margin=Decimal('-0.43561435861342959823'), i_category=None, i_class='rock', lochierarchy=0, rank_within_parent=36),
#  Row(gross_margin=Decimal('-0.43550771956473883152'), i_category=None, i_class='maternity', lochierarchy=0, rank_within_parent=37),
#  Row(gross_margin=Decimal('-0.43527663623738803430'), i_category=None, i_class=None, lochierarchy=0, rank_within_parent=38),
#  Row(gross_margin=Decimal('-0.43501597744051964618'), i_category=None, i_class='kids', lochierarchy=0, rank_within_parent=39),
#  Row(gross_margin=Decimal('-0.43495471799620629023'), i_category=None, i_class='camping', lochierarchy=0, rank_within_parent=40),
#  Row(gross_margin=Decimal('-0.43473993133124046911'), i_category=None, i_class='golf', lochierarchy=0, rank_within_parent=41),
#  Row(gross_margin=Decimal('-0.43463769267498883720'), i_category='Books', i_class='fiction', lochierarchy=0, rank_within_parent=1),
#  Row(gross_margin=Decimal('-0.43452776378667850951'), i_category='Books', i_class='reference', lochierarchy=0, rank_within_parent=2),
#  Row(gross_margin=Decimal('-0.43447486026854350876'), i_category='Books', i_class=None, lochierarchy=0, rank_within_parent=3),
#  Row(gross_margin=Decimal('-0.43447020920809058183'), i_category='Books', i_class='computers', lochierarchy=0, rank_within_parent=4),
#  Row(gross_margin=Decimal('-0.43428999042082383658'), i_category=None, i_class='romance', lochierarchy=0, rank_within_parent=42),
#  Row(gross_margin=Decimal('-0.43422584143830548495'), i_category='Books', i_class='cooking', lochierarchy=0, rank_within_parent=5),
#  Row(gross_margin=Decimal('-0.43414366878464396368'), i_category=None, i_class='infants', lochierarchy=0, rank_within_parent=43),
#  Row(gross_margin=Decimal('-0.43404897731623584759'), i_category='Books', i_class='history', lochierarchy=0, rank_within_parent=6),
#  Row(gross_margin=Decimal('-0.43376882693575818716'), i_category='Jewelry', i_class=None, lochierarchy=1, rank_within_parent=2),
#  Row(gross_margin=Decimal('-0.43371349466003111712'), i_category='Music', i_class=None, lochierarchy=1, rank_within_parent=3),
#  Row(gross_margin=Decimal('-0.43367159423014962013'), i_category='Sports', i_class=None, lochierarchy=1, rank_within_parent=4),
#  Row(gross_margin=Decimal('-0.43360519550777610415'), i_category='Men', i_class=None, lochierarchy=1, rank_within_parent=5),
#  Row(gross_margin=Decimal('-0.43358989475350213383'), i_category='Women', i_class=None, lochierarchy=1, rank_within_parent=6),
#  Row(gross_margin=Decimal('-0.43358627728306443926'), i_category=None, i_class=None, lochierarchy=2, rank_within_parent=1),
#  Row(gross_margin=Decimal('-0.43353995228987259047'), i_category='Shoes', i_class=None, lochierarchy=1, rank_within_parent=7),
#  Row(gross_margin=Decimal('-0.43353747033700003969'), i_category='Books', i_class=None, lochierarchy=1, rank_within_parent=8),
#  Row(gross_margin=Decimal('-0.43349539873648945556'), i_category='Children', i_class=None, lochierarchy=1, rank_within_parent=9),
#  Row(gross_margin=Decimal('-0.43348694025710119921'), i_category='Home', i_class=None, lochierarchy=1, rank_within_parent=10),
#  Row(gross_margin=Decimal('-0.43342670574593757218'), i_category=None, i_class='toddlers', lochierarchy=0, rank_within_parent=44),
#  Row(gross_margin=Decimal('-0.43340485165479664221'), i_category='Electronics', i_class=None, lochierarchy=1, rank_within_parent=11),
#  Row(gross_margin=Decimal('-0.43340446329714668500'), i_category=None, i_class='musical', lochierarchy=0, rank_within_parent=45),
#  Row(gross_margin=Decimal('-0.43326865631149291828'), i_category=None, i_class='reference', lochierarchy=0, rank_within_parent=46),
#  Row(gross_margin=Decimal('-0.43325549083761292687'), i_category=None, i_class='diamonds', lochierarchy=0, rank_within_parent=47),
#  Row(gross_margin=Decimal('-0.43193082872314780811'), i_category=None, i_class='athletic', lochierarchy=0, rank_within_parent=48),
#  Row(gross_margin=Decimal('-0.43181629529070380726'), i_category=None, i_class='tennis', lochierarchy=0, rank_within_parent=49),
#  Row(gross_margin=Decimal('-0.43173620765961707768'), i_category=None, i_class='lighting', lochierarchy=0, rank_within_parent=50),
#  Row(gross_margin=Decimal('-0.43137253755689801662'), i_category=None, i_class='basketball', lochierarchy=0, rank_within_parent=51),
#  Row(gross_margin=Decimal('-0.43062608877945132099'), i_category=None, i_class='optics', lochierarchy=0, rank_within_parent=52),
#  Row(gross_margin=Decimal('-0.42926236666984711593'), i_category=None, i_class='arts', lochierarchy=0, rank_within_parent=53),
#  Row(gross_margin=Decimal('-0.42885057637972905225'), i_category=None, i_class='disk drives', lochierarchy=0, rank_within_parent=54),
#  Row(gross_margin=Decimal('-0.42883895337303757123'), i_category=None, i_class='earings', lochierarchy=0, rank_within_parent=55),
#  Row(gross_margin=Decimal('-0.42815705038826697011'), i_category=None, i_class='scanners', lochierarchy=0, rank_within_parent=56),
#  Row(gross_margin=Decimal('-0.42789628991180642042'), i_category=None, i_class='flatware', lochierarchy=0, rank_within_parent=57),
#  Row(gross_margin=Decimal('-0.42751393108325494927'), i_category=None, i_class='rugs', lochierarchy=0, rank_within_parent=58),
#  Row(gross_margin=Decimal('-0.42703891331468818542'), i_category=None, i_class='computers', lochierarchy=0, rank_within_parent=59),
#  Row(gross_margin=Decimal('-0.42687500164053020735'), i_category=None, i_class='glassware', lochierarchy=0, rank_within_parent=60),
#  Row(gross_margin=Decimal('-0.42552101984012148225'), i_category=None, i_class='fishing', lochierarchy=0, rank_within_parent=61),
#  Row(gross_margin=Decimal('-0.42476260982538582676'), i_category=None, i_class='womens watch', lochierarchy=0, rank_within_parent=62),
#  Row(gross_margin=Decimal('-0.42452851303971651810'), i_category=None, i_class='parenting', lochierarchy=0, rank_within_parent=63),
#  Row(gross_margin=Decimal('-0.42339149149768885699'), i_category=None, i_class='furniture', lochierarchy=0, rank_within_parent=64),
#  Row(gross_margin=Decimal('-0.42168352304902960657'), i_category=None, i_class='outdoor', lochierarchy=0, rank_within_parent=65),
#  Row(gross_margin=Decimal('-0.42143177556841967050'), i_category=None, i_class='curtains/drapes', lochierarchy=0, rank_within_parent=66),
#  Row(gross_margin=Decimal('-0.42120834921200342268'), i_category=None, i_class='dresses', lochierarchy=0, rank_within_parent=67),
#  Row(gross_margin=Decimal('-0.42001482343846840492'), i_category=None, i_class='pop', lochierarchy=0, rank_within_parent=68),
#  Row(gross_margin=Decimal('-0.41995134951751466646'), i_category=None, i_class='karoke', lochierarchy=0, rank_within_parent=69),
#  Row(gross_margin=Decimal('-0.41959982259002413551'), i_category=None, i_class='sports', lochierarchy=0, rank_within_parent=70),
#  Row(gross_margin=Decimal('-0.41650088646249658534'), i_category=None, i_class='custom', lochierarchy=0, rank_within_parent=71),
#  Row(gross_margin=Decimal('-0.41588027531636796036'), i_category=None, i_class='automotive', lochierarchy=0, rank_within_parent=72),
#  Row(gross_margin=Decimal('-0.41500139895405487419'), i_category=None, i_class='travel', lochierarchy=0, rank_within_parent=73),
#  Row(gross_margin=Decimal('-0.41484497717797805148'), i_category=None, i_class='loose stones', lochierarchy=0, rank_within_parent=74),
#  Row(gross_margin=Decimal('-0.41046619711072709563'), i_category=None, i_class='football', lochierarchy=0, rank_within_parent=75),
#  Row(gross_margin=Decimal('-0.40766856021119107858'), i_category=None, i_class='rings', lochierarchy=0, rank_within_parent=76),
#  Row(gross_margin=Decimal('-0.40507693120675812824'), i_category=None, i_class='home repair', lochierarchy=0, rank_within_parent=77),
#  Row(gross_margin=Decimal('-0.40306239716291443732'), i_category=None, i_class='portable', lochierarchy=0, rank_within_parent=78),
#  Row(gross_margin=Decimal('-0.40118362437320425343'), i_category=None, i_class='estate', lochierarchy=0, rank_within_parent=79),
#  Row(gross_margin=Decimal('-0.40118360571745636940'), i_category=None, i_class='athletic shoes', lochierarchy=0, rank_within_parent=80),
#  Row(gross_margin=Decimal('-0.39111306499480281681'), i_category=None, i_class='monitors', lochierarchy=0, rank_within_parent=81),
#  Row(gross_margin=Decimal('-0.36708489506031944778'), i_category=None, i_class='semi-precious', lochierarchy=0, rank_within_parent=82)]
# ######### END Full GPU OUTPUT for REFERENCE #####
# #### checking diff qid='q36' use_decimal=True ####
# #### SUCSESS qid='q36' use_decimal=True GPU and CPU matched ####
# ##### Runing qid='q86' use_decimal=True on CPU #####
# root
#  |-- total_sum: decimal(17,2) (nullable = true)
#  |-- i_category: string (nullable = true)
#  |-- i_class: string (nullable = true)
#  |-- lochierarchy: byte (nullable = false)
#  |-- rank_within_parent: integer (nullable = false)
#
# ######### BEGIN Full CPU OUTPUT for REFERENCE #####
# [Row(total_sum=Decimal('1234546.72'), i_category=None, i_class='karoke', lochierarchy=0, rank_within_parent=90),
#  Row(total_sum=Decimal('1254109.66'), i_category=None, i_class='fishing', lochierarchy=0, rank_within_parent=89),
#  Row(total_sum=Decimal('1342282.92'), i_category=None, i_class='optics', lochierarchy=0, rank_within_parent=88),
#  Row(total_sum=Decimal('1351109.60'), i_category=None, i_class='football', lochierarchy=0, rank_within_parent=87),
#  Row(total_sum=Decimal('1425651.04'), i_category=None, i_class='birdal', lochierarchy=0, rank_within_parent=86),
#  Row(total_sum=Decimal('3930062.04'), i_category=None, i_class='camcorders', lochierarchy=0, rank_within_parent=85),
#  Row(total_sum=Decimal('3945730.60'), i_category=None, i_class='furniture', lochierarchy=0, rank_within_parent=84),
#  Row(total_sum=Decimal('4150307.82'), i_category=None, i_class='portable', lochierarchy=0, rank_within_parent=83),
#  Row(total_sum=Decimal('4207979.85'), i_category=None, i_class='romance', lochierarchy=0, rank_within_parent=82),
#  Row(total_sum=Decimal('4252926.97'), i_category=None, i_class='mens watch', lochierarchy=0, rank_within_parent=81),
#  Row(total_sum=Decimal('4306098.49'), i_category=None, i_class='mattresses', lochierarchy=0, rank_within_parent=80),
#  Row(total_sum=Decimal('4332160.20'), i_category=None, i_class='bedding', lochierarchy=0, rank_within_parent=79),
#  Row(total_sum=Decimal('4387582.13'), i_category=None, i_class='tennis', lochierarchy=0, rank_within_parent=78),
#  Row(total_sum=Decimal('4389978.04'), i_category=None, i_class='mystery', lochierarchy=0, rank_within_parent=77),
#  Row(total_sum=Decimal('4396841.01'), i_category=None, i_class='arts', lochierarchy=0, rank_within_parent=76),
#  Row(total_sum=Decimal('5161611.81'), i_category=None, i_class='musical', lochierarchy=0, rank_within_parent=75),
#  Row(total_sum=Decimal('5260865.59'), i_category=None, i_class='home repair', lochierarchy=0, rank_within_parent=74),
#  Row(total_sum=Decimal('5297938.28'), i_category=None, i_class='automotive', lochierarchy=0, rank_within_parent=73),
#  Row(total_sum=Decimal('5307426.24'), i_category=None, i_class='cooking', lochierarchy=0, rank_within_parent=72),
#  Row(total_sum=Decimal('5394054.72'), i_category=None, i_class='consignment', lochierarchy=0, rank_within_parent=71),
#  Row(total_sum=Decimal('5428890.18'), i_category=None, i_class='accent', lochierarchy=0, rank_within_parent=70),
#  Row(total_sum=Decimal('5443241.76'), i_category=None, i_class='personal', lochierarchy=0, rank_within_parent=69),
#  Row(total_sum=Decimal('5481274.22'), i_category=None, i_class='self-help', lochierarchy=0, rank_within_parent=68),
#  Row(total_sum=Decimal('5486660.40'), i_category=None, i_class='golf', lochierarchy=0, rank_within_parent=67),
#  Row(total_sum=Decimal('5500424.77'), i_category=None, i_class='stereo', lochierarchy=0, rank_within_parent=66),
#  Row(total_sum=Decimal('5506940.31'), i_category=None, i_class='fitness', lochierarchy=0, rank_within_parent=65),
#  Row(total_sum=Decimal('5517099.45'), i_category=None, i_class='sailing', lochierarchy=0, rank_within_parent=64),
#  Row(total_sum=Decimal('5560295.37'), i_category=None, i_class='flatware', lochierarchy=0, rank_within_parent=63),
#  Row(total_sum=Decimal('5642837.10'), i_category=None, i_class='entertainments', lochierarchy=0, rank_within_parent=62),
#  Row(total_sum=Decimal('5647666.28'), i_category=None, i_class='tables', lochierarchy=0, rank_within_parent=61),
#  Row(total_sum=Decimal('5657711.65'), i_category=None, i_class='scanners', lochierarchy=0, rank_within_parent=60),
#  Row(total_sum=Decimal('5724504.78'), i_category=None, i_class='costume', lochierarchy=0, rank_within_parent=59),
#  Row(total_sum=Decimal('5736453.24'), i_category=None, i_class='lighting', lochierarchy=0, rank_within_parent=58),
#  Row(total_sum=Decimal('5753043.50'), i_category=None, i_class='paint', lochierarchy=0, rank_within_parent=57),
#  Row(total_sum=Decimal('5903827.55'), i_category=None, i_class='monitors', lochierarchy=0, rank_within_parent=56),
#  Row(total_sum=Decimal('6619948.32'), i_category=None, i_class='outdoor', lochierarchy=0, rank_within_parent=55),
#  Row(total_sum=Decimal('6667210.50'), i_category=None, i_class='womens watch', lochierarchy=0, rank_within_parent=54),
#  Row(total_sum=Decimal('6692527.92'), i_category=None, i_class='computers', lochierarchy=0, rank_within_parent=53),
#  Row(total_sum=Decimal('6706763.97'), i_category=None, i_class='parenting', lochierarchy=0, rank_within_parent=52),
#  Row(total_sum=Decimal('6852563.03'), i_category=None, i_class='guns', lochierarchy=0, rank_within_parent=51),
#  Row(total_sum=Decimal('8199342.82'), i_category=None, i_class='accessories', lochierarchy=0, rank_within_parent=50),
#  Row(total_sum=Decimal('9337722.26'), i_category=None, i_class='school-uniforms', lochierarchy=0, rank_within_parent=49),
#  Row(total_sum=Decimal('9582523.07'), i_category=None, i_class='custom', lochierarchy=0, rank_within_parent=48),
#  Row(total_sum=Decimal('9584516.63'), i_category=None, i_class='wallpaper', lochierarchy=0, rank_within_parent=47),
#  Row(total_sum=Decimal('9740138.50'), i_category=None, i_class='audio', lochierarchy=0, rank_within_parent=46),
#  Row(total_sum=Decimal('9750562.25'), i_category=None, i_class='baseball', lochierarchy=0, rank_within_parent=45),
#  Row(total_sum=Decimal('9955396.61'), i_category=None, i_class='athletic shoes', lochierarchy=0, rank_within_parent=44),
#  Row(total_sum=Decimal('10901848.38'), i_category=None, i_class='reference', lochierarchy=0, rank_within_parent=43),
#  Row(total_sum=Decimal('10932701.74'), i_category=None, i_class='maternity', lochierarchy=0, rank_within_parent=42),
#  Row(total_sum=Decimal('11338010.10'), i_category=None, i_class='travel', lochierarchy=0, rank_within_parent=41),
#  Row(total_sum=Decimal('11345439.81'), i_category=None, i_class='rugs', lochierarchy=0, rank_within_parent=40),
#  Row(total_sum=Decimal('11383889.14'), i_category=None, i_class='camping', lochierarchy=0, rank_within_parent=39),
#  Row(total_sum=Decimal('11786736.03'), i_category=None, i_class='science', lochierarchy=0, rank_within_parent=38),
#  Row(total_sum=Decimal('12192409.33'), i_category=None, i_class='glassware', lochierarchy=0, rank_within_parent=37),
#  Row(total_sum=Decimal('12379089.13'), i_category=None, i_class='curtains/drapes', lochierarchy=0, rank_within_parent=36),
#  Row(total_sum=Decimal('12511944.08'), i_category=None, i_class='loose stones', lochierarchy=0, rank_within_parent=35),
#  Row(total_sum=Decimal('13968103.72'), i_category=None, i_class='basketball', lochierarchy=0, rank_within_parent=34),
#  Row(total_sum=Decimal('14046274.99'), i_category=None, i_class='business', lochierarchy=0, rank_within_parent=33),
#  Row(total_sum=Decimal('14590130.94'), i_category=None, i_class='classical', lochierarchy=0, rank_within_parent=32),
#  Row(total_sum=Decimal('14902687.98'), i_category=None, i_class='history', lochierarchy=0, rank_within_parent=31),
#  Row(total_sum=Decimal('14975074.05'), i_category=None, i_class='semi-precious', lochierarchy=0, rank_within_parent=30),
#  Row(total_sum=Decimal('15174058.86'), i_category=None, i_class='archery', lochierarchy=0, rank_within_parent=29),
#  Row(total_sum=Decimal('15191474.73'), i_category=None, i_class='sports', lochierarchy=0, rank_within_parent=28),
#  Row(total_sum=Decimal('15357709.06'), i_category=None, i_class='decor', lochierarchy=0, rank_within_parent=27),
#  Row(total_sum=Decimal('15514866.49'), i_category=None, i_class='disk drives', lochierarchy=0, rank_within_parent=26),
#  Row(total_sum=Decimal('15529488.41'), i_category=None, i_class='televisions', lochierarchy=0, rank_within_parent=25),
#  Row(total_sum=Decimal('16279508.99'), i_category=None, i_class='earings', lochierarchy=0, rank_within_parent=24),
#  Row(total_sum=Decimal('16571607.40'), i_category=None, i_class='estate', lochierarchy=0, rank_within_parent=23),
#  Row(total_sum=Decimal('16756809.91'), i_category=None, i_class='bracelets', lochierarchy=0, rank_within_parent=22),
#  Row(total_sum=Decimal('17721131.07'), i_category=None, i_class='dvd/vcr players', lochierarchy=0, rank_within_parent=21),
#  Row(total_sum=Decimal('18029719.40'), i_category=None, i_class='pendants', lochierarchy=0, rank_within_parent=20),
#  Row(total_sum=Decimal('18386031.17'), i_category=None, i_class='diamonds', lochierarchy=0, rank_within_parent=19),
#  Row(total_sum=Decimal('19853288.95'), i_category=None, i_class='pop', lochierarchy=0, rank_within_parent=18),
#  Row(total_sum=Decimal('21681003.06'), i_category=None, i_class='rock', lochierarchy=0, rank_within_parent=17),
#  Row(total_sum=Decimal('22418201.69'), i_category=None, i_class='memory', lochierarchy=0, rank_within_parent=16),
#  Row(total_sum=Decimal('23316843.00'), i_category=None, i_class='kids', lochierarchy=0, rank_within_parent=15),
#  Row(total_sum=Decimal('28193001.31'), i_category=None, i_class='athletic', lochierarchy=0, rank_within_parent=14),
#  Row(total_sum=Decimal('29563410.13'), i_category=None, i_class='mens', lochierarchy=0, rank_within_parent=13),
#  Row(total_sum=Decimal('31131748.58'), i_category=None, i_class='sports-apparel', lochierarchy=0, rank_within_parent=12),
#  Row(total_sum=Decimal('31249700.11'), i_category=None, i_class='pants', lochierarchy=0, rank_within_parent=11),
#  Row(total_sum=Decimal('32024665.59'), i_category=None, i_class='toddlers', lochierarchy=0, rank_within_parent=10),
#  Row(total_sum=Decimal('33814176.18'), i_category=None, i_class='dresses', lochierarchy=0, rank_within_parent=9),
#  Row(total_sum=Decimal('34045345.66'), i_category=None, i_class='country', lochierarchy=0, rank_within_parent=8),
#  Row(total_sum=Decimal('36812193.32'), i_category=None, i_class='fragrances', lochierarchy=0, rank_within_parent=7),
#  Row(total_sum=Decimal('40080937.87'), i_category=None, i_class='infants', lochierarchy=0, rank_within_parent=6),
#  Row(total_sum=Decimal('41757699.36'), i_category=None, i_class='swimwear', lochierarchy=0, rank_within_parent=5),
#  Row(total_sum=Decimal('43799567.42'), i_category=None, i_class='womens', lochierarchy=0, rank_within_parent=4),
#  Row(total_sum=Decimal('44302354.33'), i_category=None, i_class='shirts', lochierarchy=0, rank_within_parent=3),
#  Row(total_sum=Decimal('49342907.51'), i_category=None, i_class='newborn', lochierarchy=0, rank_within_parent=2),
#  Row(total_sum=Decimal('101454864.01'), i_category='Shoes', i_class=None, lochierarchy=0, rank_within_parent=5),
#  Row(total_sum=Decimal('101863331.68'), i_category='Electronics', i_class=None, lochierarchy=0, rank_within_parent=17),
#  Row(total_sum=Decimal('118764065.06'), i_category='Jewelry', i_class=None, lochierarchy=0, rank_within_parent=17),
#  Row(total_sum=Decimal('124256332.74'), i_category='Sports', i_class=None, lochierarchy=0, rank_within_parent=17),
#  Row(total_sum=Decimal('130116199.43'), i_category='Children', i_class=None, lochierarchy=0, rank_within_parent=5),
#  Row(total_sum=Decimal('135084268.34'), i_category='Home', i_class=None, lochierarchy=0, rank_within_parent=17),
#  Row(total_sum=Decimal('141812983.07'), i_category='Books', i_class=None, lochierarchy=0, rank_within_parent=17),
#  Row(total_sum=Decimal('142206650.79'), i_category='Women', i_class=None, lochierarchy=0, rank_within_parent=5),
#  Row(total_sum=Decimal('158480951.82'), i_category='Men', i_class=None, lochierarchy=0, rank_within_parent=5),
#  Row(total_sum=Decimal('164060832.84'), i_category='Music', i_class=None, lochierarchy=0, rank_within_parent=5),
#  Row(total_sum=Decimal('1244069328.50'), i_category=None, i_class=None, lochierarchy=0, rank_within_parent=1),
#  Row(total_sum=Decimal('2424232467.65'), i_category=None, i_class=None, lochierarchy=1, rank_within_parent=11),
#  Row(total_sum=Decimal('5803323982.81'), i_category='Sports', i_class='tennis', lochierarchy=0, rank_within_parent=16),
#  Row(total_sum=Decimal('5804340819.12'), i_category='Jewelry', i_class='semi-precious', lochierarchy=0, rank_within_parent=16),
#  Row(total_sum=Decimal('5810546842.57'), i_category='Jewelry', i_class='loose stones', lochierarchy=0, rank_within_parent=15),
#  Row(total_sum=Decimal('5811042467.71'), i_category='Electronics', i_class='audio', lochierarchy=0, rank_within_parent=16),
#  Row(total_sum=Decimal('5844540891.64'), i_category='Books', i_class='computers', lochierarchy=0, rank_within_parent=16),
#  Row(total_sum=Decimal('5867687274.65'), i_category='Home', i_class='accent', lochierarchy=0, rank_within_parent=16),
#  Row(total_sum=Decimal('5874108877.79'), i_category='Electronics', i_class='wireless', lochierarchy=0, rank_within_parent=15),
#  Row(total_sum=Decimal('5879209245.99'), i_category='Books', i_class='science', lochierarchy=0, rank_within_parent=15),
#  Row(total_sum=Decimal('5904053505.55'), i_category='Jewelry', i_class='custom', lochierarchy=0, rank_within_parent=14),
#  Row(total_sum=Decimal('5919822947.48'), i_category='Books', i_class='mystery', lochierarchy=0, rank_within_parent=14),
#  Row(total_sum=Decimal('5925233287.53'), i_category='Jewelry', i_class='diamonds', lochierarchy=0, rank_within_parent=13),
#  Row(total_sum=Decimal('5933114786.73'), i_category='Electronics', i_class='musical', lochierarchy=0, rank_within_parent=14),
#  Row(total_sum=Decimal('5948786439.59'), i_category='Jewelry', i_class='pendants', lochierarchy=0, rank_within_parent=12),
#  Row(total_sum=Decimal('5977033622.19'), i_category='Home', i_class='wallpaper', lochierarchy=0, rank_within_parent=15),
#  Row(total_sum=Decimal('5980163174.30'), i_category='Sports', i_class='sailing', lochierarchy=0, rank_within_parent=15),
#  Row(total_sum=Decimal('5982691026.55'), i_category='Books', i_class='arts', lochierarchy=0, rank_within_parent=13),
#  Row(total_sum=Decimal('5988919180.20'), i_category='Jewelry', i_class='consignment', lochierarchy=0, rank_within_parent=11),
#  Row(total_sum=Decimal('5991728440.44'), i_category='Jewelry', i_class='earings', lochierarchy=0, rank_within_parent=10),
#  Row(total_sum=Decimal('6009166638.31'), i_category='Sports', i_class='hockey', lochierarchy=0, rank_within_parent=14),
#  Row(total_sum=Decimal('6015387881.75'), i_category='Home', i_class='paint', lochierarchy=0, rank_within_parent=14),
#  Row(total_sum=Decimal('6016911005.47'), i_category='Home', i_class='tables', lochierarchy=0, rank_within_parent=13),
#  Row(total_sum=Decimal('6017662048.64'), i_category='Home', i_class='kids', lochierarchy=0, rank_within_parent=12),
#  Row(total_sum=Decimal('6020306051.54'), i_category='Home', i_class='mattresses', lochierarchy=0, rank_within_parent=11),
#  Row(total_sum=Decimal('6030955968.86'), i_category='Home', i_class='decor', lochierarchy=0, rank_within_parent=10),
#  Row(total_sum=Decimal('6031941567.98'), i_category='Jewelry', i_class='birdal', lochierarchy=0, rank_within_parent=9),
#  Row(total_sum=Decimal('6032169038.25'), i_category='Electronics', i_class='cameras', lochierarchy=0, rank_within_parent=13),
#  Row(total_sum=Decimal('6052804826.04'), i_category='Books', i_class='entertainments', lochierarchy=0, rank_within_parent=12),
#  Row(total_sum=Decimal('6059616299.03'), i_category='Home', i_class='glassware', lochierarchy=0, rank_within_parent=9),
#  Row(total_sum=Decimal('6065871355.25'), i_category='Home', i_class='lighting', lochierarchy=0, rank_within_parent=8),
#  Row(total_sum=Decimal('6071798950.73'), i_category='Jewelry', i_class='estate', lochierarchy=0, rank_within_parent=8),
#  Row(total_sum=Decimal('6076324929.77'), i_category='Books', i_class='parenting', lochierarchy=0, rank_within_parent=11),
#  Row(total_sum=Decimal('6080857572.41'), i_category='Electronics', i_class='automotive', lochierarchy=0, rank_within_parent=12),
#  Row(total_sum=Decimal('6084747767.54'), i_category='Electronics', i_class='stereo', lochierarchy=0, rank_within_parent=11),
#  Row(total_sum=Decimal('6093261693.21'), i_category='Books', i_class='travel', lochierarchy=0, rank_within_parent=10),
#  Row(total_sum=Decimal('6107377024.88'), i_category='Books', i_class='business', lochierarchy=0, rank_within_parent=9),
#  Row(total_sum=Decimal('6125629680.64'), i_category='Home', i_class='furniture', lochierarchy=0, rank_within_parent=7),
#  Row(total_sum=Decimal('6129289774.59'), i_category='Electronics', i_class='portable', lochierarchy=0, rank_within_parent=10),
#  Row(total_sum=Decimal('6135599134.76'), i_category='Sports', i_class='athletic shoes', lochierarchy=0, rank_within_parent=13),
#  Row(total_sum=Decimal('6146225670.72'), i_category='Electronics', i_class='monitors', lochierarchy=0, rank_within_parent=9),
#  Row(total_sum=Decimal('6150610861.96'), i_category='Electronics', i_class='personal', lochierarchy=0, rank_within_parent=8),
#  Row(total_sum=Decimal('6158433646.37'), i_category='Jewelry', i_class='costume', lochierarchy=0, rank_within_parent=7),
#  Row(total_sum=Decimal('6163875965.70'), i_category='Home', i_class='curtains/drapes', lochierarchy=0, rank_within_parent=6),
#  Row(total_sum=Decimal('6164306474.16'), i_category='Sports', i_class='guns', lochierarchy=0, rank_within_parent=12),
#  Row(total_sum=Decimal('6171100859.45'), i_category='Sports', i_class='fishing', lochierarchy=0, rank_within_parent=11),
#  Row(total_sum=Decimal('6174718545.60'), i_category='Books', i_class='self-help', lochierarchy=0, rank_within_parent=8),
#  Row(total_sum=Decimal('6175419065.35'), i_category='Electronics', i_class='disk drives', lochierarchy=0, rank_within_parent=7),
#  Row(total_sum=Decimal('6176731579.84'), i_category='Books', i_class='romance', lochierarchy=0, rank_within_parent=7),
#  Row(total_sum=Decimal('6188611196.70'), i_category='Sports', i_class='archery', lochierarchy=0, rank_within_parent=10),
#  Row(total_sum=Decimal('6191352945.32'), i_category='Electronics', i_class='camcorders', lochierarchy=0, rank_within_parent=6),
#  Row(total_sum=Decimal('6191602998.37'), i_category='Jewelry', i_class='bracelets', lochierarchy=0, rank_within_parent=6),
#  Row(total_sum=Decimal('6194858913.56'), i_category='Sports', i_class='basketball', lochierarchy=0, rank_within_parent=9),
#  Row(total_sum=Decimal('6215497389.92'), i_category='Jewelry', i_class='gold', lochierarchy=0, rank_within_parent=5),
#  Row(total_sum=Decimal('6220670485.86'), i_category='Books', i_class='home repair', lochierarchy=0, rank_within_parent=6),
#  Row(total_sum=Decimal('6224371673.43'), i_category='Sports', i_class='fitness', lochierarchy=0, rank_within_parent=8),
#  Row(total_sum=Decimal('6230467027.74'), i_category='Books', i_class='fiction', lochierarchy=0, rank_within_parent=5),
#  Row(total_sum=Decimal('6231549883.41'), i_category='Books', i_class='sports', lochierarchy=0, rank_within_parent=4),
#  Row(total_sum=Decimal('6246271775.32'), i_category='Sports', i_class='baseball', lochierarchy=0, rank_within_parent=7),
#  Row(total_sum=Decimal('6262421881.28'), i_category='Electronics', i_class='scanners', lochierarchy=0, rank_within_parent=5),
#  Row(total_sum=Decimal('6275813242.65'), i_category='Electronics', i_class='memory', lochierarchy=0, rank_within_parent=4),
#  Row(total_sum=Decimal('6282821953.35'), i_category='Home', i_class='rugs', lochierarchy=0, rank_within_parent=5),
#  Row(total_sum=Decimal('6286117760.39'), i_category='Books', i_class='reference', lochierarchy=0, rank_within_parent=3),
#  Row(total_sum=Decimal('6289497393.23'), i_category='Electronics', i_class='dvd/vcr players', lochierarchy=0, rank_within_parent=3),
#  Row(total_sum=Decimal('6290883585.88'), i_category='Sports', i_class='outdoor', lochierarchy=0, rank_within_parent=6),
#  Row(total_sum=Decimal('6302804691.31'), i_category='Sports', i_class='football', lochierarchy=0, rank_within_parent=5),
#  Row(total_sum=Decimal('6351839363.92'), i_category='Jewelry', i_class='mens watch', lochierarchy=0, rank_within_parent=4),
#  Row(total_sum=Decimal('6355005756.64'), i_category='Books', i_class='cooking', lochierarchy=0, rank_within_parent=2),
#  Row(total_sum=Decimal('6361556417.59'), i_category='Electronics', i_class='karoke', lochierarchy=0, rank_within_parent=2),
#  Row(total_sum=Decimal('6367620303.44'), i_category='Home', i_class='bathroom', lochierarchy=0, rank_within_parent=4),
#  Row(total_sum=Decimal('6380683176.63'), i_category='Home', i_class='flatware', lochierarchy=0, rank_within_parent=3),
#  Row(total_sum=Decimal('6382186428.72'), i_category='Books', i_class='history', lochierarchy=0, rank_within_parent=1),
#  Row(total_sum=Decimal('6387310431.88'), i_category='Jewelry', i_class='womens watch', lochierarchy=0, rank_within_parent=3),
#  Row(total_sum=Decimal('6389757845.68'), i_category='Home', i_class='blinds/shades', lochierarchy=0, rank_within_parent=2),
#  Row(total_sum=Decimal('6397795748.79'), i_category='Sports', i_class='camping', lochierarchy=0, rank_within_parent=4),
#  Row(total_sum=Decimal('6406719769.48'), i_category='Home', i_class='bedding', lochierarchy=0, rank_within_parent=1),
# ...
# -Row(total_sum=Decimal('24967476442.69'), i_category='Women', i_class='maternity', lochierarchy=0, rank_within_parent=1)
# -Row(total_sum=Decimal('25013631301.76'), i_category='Children', i_class='toddlers', lochierarchy=0, rank_within_parent=2)
# -Row(total_sum=Decimal('25340524137.86'), i_category='Children', i_class='infants', lochierarchy=0, rank_within_parent=1)
# -Row(total_sum=Decimal('97910573031.71'), i_category='Men', i_class=None, lochierarchy=1, rank_within_parent=10)
# -Row(total_sum=Decimal('98122283042.75'), i_category='Jewelry', i_class=None, lochierarchy=1, rank_within_parent=9)
# -Row(total_sum=Decimal('98155293036.83'), i_category='Books', i_class=None, lochierarchy=1, rank_within_parent=8)
# -Row(total_sum=Decimal('98263334349.09'), i_category='Shoes', i_class=None, lochierarchy=1, rank_within_parent=7)
# -Row(total_sum=Decimal('98323624470.64'), i_category='Home', i_class=None, lochierarchy=1, rank_within_parent=6)
# -Row(total_sum=Decimal('98526876882.18'), i_category='Electronics', i_class=None, lochierarchy=1, rank_within_parent=5)
# -Row(total_sum=Decimal('98645681248.07'), i_category='Music', i_class=None, lochierarchy=1, rank_within_parent=4)
# -Row(total_sum=Decimal('99005463489.62'), i_category='Women', i_class=None, lochierarchy=1, rank_within_parent=3)
# -Row(total_sum=Decimal('99377245192.39'), i_category='Children', i_class=None, lochierarchy=1, rank_within_parent=2)
# -Row(total_sum=Decimal('99595908382.56'), i_category='Sports', i_class=None, lochierarchy=1, rank_within_parent=1)
# -Row(total_sum=Decimal('988350515593.49'), i_category=None, i_class=None, lochierarchy=2, rank_within_parent=1)
# +Row(total_sum=Decimal('1244063695.27'), i_category=None, i_class=None, lochierarchy=0, rank_within_parent=1)
# +Row(total_sum=Decimal('2424171563.35'), i_category=None, i_class=None, lochierarchy=1, rank_within_parent=11)
# +Row(total_sum=Decimal('5803283137.28'), i_category='Sports', i_class='tennis', lochierarchy=0, rank_within_parent=16)
# +Row(total_sum=Decimal('5804313573.32'), i_category='Jewelry', i_class='semi-precious', lochierarchy=0, rank_within_parent=16)
# +Row(total_sum=Decimal('5810473570.33'), i_category='Jewelry', i_class='loose stones', lochierarchy=0, rank_within_parent=15)
# +Row(total_sum=Decimal('5810987166.71'), i_category='Electronics', i_class='audio', lochierarchy=0, rank_within_parent=16)
# +Row(total_sum=Decimal('5844516437.25'), i_category='Books', i_class='computers', lochierarchy=0, rank_within_parent=16)
# +Row(total_sum=Decimal('5867656162.87'), i_category='Home', i_class='accent', lochierarchy=0, rank_within_parent=16)
# +Row(total_sum=Decimal('5874070252.24'), i_category='Electronics', i_class='wireless', lochierarchy=0, rank_within_parent=15)
# +Row(total_sum=Decimal('5879164378.35'), i_category='Books', i_class='science', lochierarchy=0, rank_within_parent=15)
# +Row(total_sum=Decimal('5904024742.66'), i_category='Jewelry', i_class='custom', lochierarchy=0, rank_within_parent=14)
# +Row(total_sum=Decimal('5919782282.70'), i_category='Books', i_class='mystery', lochierarchy=0, rank_within_parent=14)
# +Row(total_sum=Decimal('5925156160.44'), i_category='Jewelry', i_class='diamonds', lochierarchy=0, rank_within_parent=13)
# +Row(total_sum=Decimal('5933107651.95'), i_category='Electronics', i_class='musical', lochierarchy=0, rank_within_parent=14)
# +Row(total_sum=Decimal('5948740330.90'), i_category='Jewelry', i_class='pendants', lochierarchy=0, rank_within_parent=12)
# +Row(total_sum=Decimal('5977021741.21'), i_category='Home', i_class='wallpaper', lochierarchy=0, rank_within_parent=15)
# +Row(total_sum=Decimal('5980133518.11'), i_category='Sports', i_class='sailing', lochierarchy=0, rank_within_parent=15)
# +Row(total_sum=Decimal('5982651726.31'), i_category='Books', i_class='arts', lochierarchy=0, rank_within_parent=13)
# +Row(total_sum=Decimal('5988892314.32'), i_category='Jewelry', i_class='consignment', lochierarchy=0, rank_within_parent=11)
# +Row(total_sum=Decimal('5991635463.34'), i_category='Jewelry', i_class='earings', lochierarchy=0, rank_within_parent=10)
# +Row(total_sum=Decimal('6009129030.20'), i_category='Sports', i_class='hockey', lochierarchy=0, rank_within_parent=14)
# +Row(total_sum=Decimal('6015329480.39'), i_category='Home', i_class='paint', lochierarchy=0, rank_within_parent=14)
# +Row(total_sum=Decimal('6016902101.75'), i_category='Home', i_class='tables', lochierarchy=0, rank_within_parent=13)
# +Row(total_sum=Decimal('6017623746.91'), i_category='Home', i_class='kids', lochierarchy=0, rank_within_parent=12)
# +Row(total_sum=Decimal('6020270595.25'), i_category='Home', i_class='mattresses', lochierarchy=0, rank_within_parent=11)
# +Row(total_sum=Decimal('6030850527.90'), i_category='Home', i_class='decor', lochierarchy=0, rank_within_parent=10)
# +Row(total_sum=Decimal('6031917809.06'), i_category='Jewelry', i_class='birdal', lochierarchy=0, rank_within_parent=9)
# +Row(total_sum=Decimal('6032130790.37'), i_category='Electronics', i_class='cameras', lochierarchy=0, rank_within_parent=13)
# +Row(total_sum=Decimal('6052777330.77'), i_category='Books', i_class='entertainments', lochierarchy=0, rank_within_parent=12)
# +Row(total_sum=Decimal('6059584045.74'), i_category='Home', i_class='glassware', lochierarchy=0, rank_within_parent=9)
# +Row(total_sum=Decimal('6065840396.29'), i_category='Home', i_class='lighting', lochierarchy=0, rank_within_parent=8)
# +Row(total_sum=Decimal('6071760345.48'), i_category='Jewelry', i_class='estate', lochierarchy=0, rank_within_parent=8)
# +Row(total_sum=Decimal('6076295986.69'), i_category='Books', i_class='parenting', lochierarchy=0, rank_within_parent=11)
# +Row(total_sum=Decimal('6080791875.75'), i_category='Electronics', i_class='automotive', lochierarchy=0, rank_within_parent=12)
# +Row(total_sum=Decimal('6084727429.02'), i_category='Electronics', i_class='stereo', lochierarchy=0, rank_within_parent=11)
# +Row(total_sum=Decimal('6093254116.22'), i_category='Books', i_class='travel', lochierarchy=0, rank_within_parent=10)
# +Row(total_sum=Decimal('6107294956.84'), i_category='Books', i_class='business', lochierarchy=0, rank_within_parent=9)
# +Row(total_sum=Decimal('6125570981.70'), i_category='Home', i_class='furniture', lochierarchy=0, rank_within_parent=7)
# +Row(total_sum=Decimal('6129257755.91'), i_category='Electronics', i_class='portable', lochierarchy=0, rank_within_parent=10)
# +Row(total_sum=Decimal('6135520506.10'), i_category='Sports', i_class='athletic shoes', lochierarchy=0, rank_within_parent=13)
# +Row(total_sum=Decimal('6146188745.37'), i_category='Electronics', i_class='monitors', lochierarchy=0, rank_within_parent=9)
# +Row(total_sum=Decimal('6150575836.03'), i_category='Electronics', i_class='personal', lochierarchy=0, rank_within_parent=8)
# +Row(total_sum=Decimal('6158384478.09'), i_category='Jewelry', i_class='costume', lochierarchy=0, rank_within_parent=7)
# +Row(total_sum=Decimal('6163844323.78'), i_category='Home', i_class='curtains/drapes', lochierarchy=0, rank_within_parent=6)
# +Row(total_sum=Decimal('6164276583.76'), i_category='Sports', i_class='guns', lochierarchy=0, rank_within_parent=12)
# +Row(total_sum=Decimal('6171057450.66'), i_category='Sports', i_class='fishing', lochierarchy=0, rank_within_parent=11)
# +Row(total_sum=Decimal('6174669749.09'), i_category='Books', i_class='self-help', lochierarchy=0, rank_within_parent=8)
# +Row(total_sum=Decimal('6175366846.90'), i_category='Electronics', i_class='disk drives', lochierarchy=0, rank_within_parent=7)
# +Row(total_sum=Decimal('6176704989.59'), i_category='Books', i_class='romance', lochierarchy=0, rank_within_parent=7)
# +Row(total_sum=Decimal('6188572998.44'), i_category='Sports', i_class='archery', lochierarchy=0, rank_within_parent=10)
# +Row(total_sum=Decimal('6191276675.04'), i_category='Electronics', i_class='camcorders', lochierarchy=0, rank_within_parent=6)
# +Row(total_sum=Decimal('6191554993.27'), i_category='Jewelry', i_class='bracelets', lochierarchy=0, rank_within_parent=6)
# +Row(total_sum=Decimal('6194839713.37'), i_category='Sports', i_class='basketball', lochierarchy=0, rank_within_parent=9)
# +Row(total_sum=Decimal('6215432132.86'), i_category='Jewelry', i_class='gold', lochierarchy=0, rank_within_parent=5)
# +Row(total_sum=Decimal('6220632816.78'), i_category='Books', i_class='home repair', lochierarchy=0, rank_within_parent=6)
# +Row(total_sum=Decimal('6224329494.16'), i_category='Sports', i_class='fitness', lochierarchy=0, rank_within_parent=8)
# +Row(total_sum=Decimal('6230394523.37'), i_category='Books', i_class='fiction', lochierarchy=0, rank_within_parent=5)
# +Row(total_sum=Decimal('6231506122.34'), i_category='Books', i_class='sports', lochierarchy=0, rank_within_parent=4)
# +Row(total_sum=Decimal('6246221957.92'), i_category='Sports', i_class='baseball', lochierarchy=0, rank_within_parent=7)
# +Row(total_sum=Decimal('6262395531.53'), i_category='Electronics', i_class='scanners', lochierarchy=0, rank_within_parent=5)
# +Row(total_sum=Decimal('6275758322.87'), i_category='Electronics', i_class='memory', lochierarchy=0, rank_within_parent=4)
# +Row(total_sum=Decimal('6282743061.04'), i_category='Home', i_class='rugs', lochierarchy=0, rank_within_parent=5)
# +Row(total_sum=Decimal('6286088248.80'), i_category='Books', i_class='reference', lochierarchy=0, rank_within_parent=3)
# +Row(total_sum=Decimal('6289474427.05'), i_category='Electronics', i_class='dvd/vcr players', lochierarchy=0, rank_within_parent=3)
# +Row(total_sum=Decimal('6290787904.00'), i_category='Sports', i_class='outdoor', lochierarchy=0, rank_within_parent=6)
# +Row(total_sum=Decimal('6302743715.74'), i_category='Sports', i_class='football', lochierarchy=0, rank_within_parent=5)
# +Row(total_sum=Decimal('6351804807.68'), i_category='Jewelry', i_class='mens watch', lochierarchy=0, rank_within_parent=4)
# +Row(total_sum=Decimal('6354953846.20'), i_category='Books', i_class='cooking', lochierarchy=0, rank_within_parent=2)
# +Row(total_sum=Decimal('6361527840.47'), i_category='Electronics', i_class='karoke', lochierarchy=0, rank_within_parent=2)
# +Row(total_sum=Decimal('6367600646.86'), i_category='Home', i_class='bathroom', lochierarchy=0, rank_within_parent=4)
# +Row(total_sum=Decimal('6380658955.24'), i_category='Home', i_class='flatware', lochierarchy=0, rank_within_parent=3)
# +Row(total_sum=Decimal('6382151587.56'), i_category='Books', i_class='history', lochierarchy=0, rank_within_parent=1)
# +Row(total_sum=Decimal('6387254160.43'), i_category='Jewelry', i_class='womens watch', lochierarchy=0, rank_within_parent=3)
# +Row(total_sum=Decimal('6389676814.31'), i_category='Home', i_class='blinds/shades', lochierarchy=0, rank_within_parent=2)
# +Row(total_sum=Decimal('6397774842.75'), i_category='Sports', i_class='camping', lochierarchy=0, rank_within_parent=4)
# +Row(total_sum=Decimal('6406655891.67'), i_category='Home', i_class='bedding', lochierarchy=0, rank_within_parent=1)
# +Row(total_sum=Decimal('6419029892.19'), i_category='Sports', i_class='pools', lochierarchy=0, rank_within_parent=3)
# +Row(total_sum=Decimal('6419104920.99'), i_category='Sports', i_class='optics', lochierarchy=0, rank_within_parent=2)
# +Row(total_sum=Decimal('6448553939.21'), i_category='Jewelry', i_class='rings', lochierarchy=0, rank_within_parent=2)
# +Row(total_sum=Decimal('6524110861.76'), i_category='Sports', i_class='golf', lochierarchy=0, rank_within_parent=1)
# +Row(total_sum=Decimal('6626749292.90'), i_category='Electronics', i_class='televisions', lochierarchy=0, rank_within_parent=1)
# +Row(total_sum=Decimal('6772760400.87'), i_category='Jewelry', i_class='jewelry boxes', lochierarchy=0, rank_within_parent=1)
# +Row(total_sum=Decimal('23735476013.73'), i_category='Men', i_class='pants', lochierarchy=0, rank_within_parent=4)
# +Row(total_sum=Decimal('24099983636.71'), i_category='Children', i_class='school-uniforms', lochierarchy=0, rank_within_parent=4)
# +Row(total_sum=Decimal('24154149484.89'), i_category='Shoes', i_class='mens', lochierarchy=0, rank_within_parent=4)
# +Row(total_sum=Decimal('24280089063.61'), i_category='Music', i_class='pop', lochierarchy=0, rank_within_parent=4)
# +Row(total_sum=Decimal('24525656785.65'), i_category='Women', i_class='fragrances', lochierarchy=0, rank_within_parent=4)
# +Row(total_sum=Decimal('24540275637.48'), i_category='Men', i_class='shirts', lochierarchy=0, rank_within_parent=3)
# +Row(total_sum=Decimal('24556534593.84'), i_category='Shoes', i_class='kids', lochierarchy=0, rank_within_parent=3)
# +Row(total_sum=Decimal('24563244010.20'), i_category='Music', i_class='country', lochierarchy=0, rank_within_parent=3)
# +Row(total_sum=Decimal('24579774974.91'), i_category='Shoes', i_class='athletic', lochierarchy=0, rank_within_parent=2)
# +Row(total_sum=Decimal('24604682245.42'), i_category='Women', i_class='swimwear', lochierarchy=0, rank_within_parent=3)
# +Row(total_sum=Decimal('24641424423.52'), i_category='Men', i_class='accessories', lochierarchy=0, rank_within_parent=2)
# +Row(total_sum=Decimal('24713989821.69'), i_category='Music', i_class='rock', lochierarchy=0, rank_within_parent=2)
# +Row(total_sum=Decimal('24764803729.09'), i_category='Women', i_class='dresses', lochierarchy=0, rank_within_parent=2)
# +Row(total_sum=Decimal('24792640904.02'), i_category='Children', i_class='newborn', lochierarchy=0, rank_within_parent=3)
# +Row(total_sum=Decimal('24833963833.64'), i_category='Men', i_class='sports-apparel', lochierarchy=0, rank_within_parent=1)
# +Row(total_sum=Decimal('24870788190.85'), i_category='Shoes', i_class='womens', lochierarchy=0, rank_within_parent=1)
# +Row(total_sum=Decimal('24923514197.36'), i_category='Music', i_class='classical', lochierarchy=0, rank_within_parent=1)
# +Row(total_sum=Decimal('24967191751.68'), i_category='Women', i_class='maternity', lochierarchy=0, rank_within_parent=1)
# +Row(total_sum=Decimal('25013440284.06'), i_category='Children', i_class='toddlers', lochierarchy=0, rank_within_parent=2)
# +Row(total_sum=Decimal('25340425550.11'), i_category='Children', i_class='infants', lochierarchy=0, rank_within_parent=1)
# +Row(total_sum=Decimal('97909476788.39'), i_category='Men', i_class=None, lochierarchy=1, rank_within_parent=10)
# +Row(total_sum=Decimal('98121188160.92'), i_category='Jewelry', i_class=None, lochierarchy=1, rank_within_parent=9)
# +Row(total_sum=Decimal('98154054900.66'), i_category='Books', i_class=None, lochierarchy=1, rank_within_parent=8)
# +Row(total_sum=Decimal('98262185575.54'), i_category='Shoes', i_class=None, lochierarchy=1, rank_within_parent=7)
# +Row(total_sum=Decimal('98322545135.65'), i_category='Home', i_class=None, lochierarchy=1, rank_within_parent=6)
# +Row(total_sum=Decimal('98525742621.66'), i_category='Electronics', i_class=None, lochierarchy=1, rank_within_parent=5)
# +Row(total_sum=Decimal('98644704074.87'), i_category='Music', i_class=None, lochierarchy=1, rank_within_parent=4)
# +Row(total_sum=Decimal('99004344856.06'), i_category='Women', i_class=None, lochierarchy=1, rank_within_parent=3)
# +Row(total_sum=Decimal('99376058727.57'), i_category='Children', i_class=None, lochierarchy=1, rank_within_parent=2)
# +Row(total_sum=Decimal('99594828500.51'), i_category='Sports', i_class=None, lochierarchy=1, rank_within_parent=1)
# +Row(total_sum=Decimal('988338715460.61'), i_category=None, i_class=None, lochierarchy=2, rank_within_parent=1)
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 compare_cpu_gpu()
#
# Cell In[16], line 27, in compare_cpu_gpu()
#      21   print(f"#### checking diff {qid=} {use_decimal=} ####")
#      22   sys.stdout.writelines(unified_diff(
#      23     a=[f"{x}\n" for x in cpu],
#      24     b=[f"{x}\n" for x in gpu],
#      25     fromfile='CPU OUTPUT',
#      26     tofile='GPU OUTPUT'))
# ---> 27   assert gpu == cpu, f"##### Check for diff of {qid=} {use_decimal=} above #####"
#      28   print(f"#### SUCSESS {qid=} {use_decimal=} GPU and CPU matched ####")
#      29 print(f"##### END of REPRO on {gpu_type=} #####")
#
# AssertionError: ##### Check for diff of qid='q86' use_decimal=True above #####
